# %% [markdown]
# # EXPLORATORY DATA ANALYSIS ON DATA SCIENCE JOB SALARIES DATASET
#
#
# ## Prepared by OYEWO DAMILOLA OF 10ALYTICS

# %% [markdown]
# ## This brief requires a good EDA to be performed on Data Science Jobs salaries.

# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load data into the notebook
df = pd.read_csv(r"C:\Users\COMPUTER SCIENCE\Desktop\personal dev\INTERNSHIP\Data Scientist Salaries - EDA\ds_salaries.csv")
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.shape
# Out:
# (607, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Description of Features in the Dataset

# %% [markdown]
# ## work_year====== The year the salary was paid.
#
#
# ## experience_level	The experience level in the job during the year with the following possible values:
#
# ## EN Entry-level / Junior        MI Mid-level / Intermediate          SE Senior-level / Expert             EX Executive-level / Director
#
#
# ## employment_type	The type of employement for the role: PT Part-time        FT Full-time         CT Contract         FL Freelance
#
#
# ## job_title	The role worked in during the year.
#
#
# ## salary	The total gross salary amount paid.
#
# ## salary_currency	The currency of the salary paid as an ISO 4217 currency code.
#
#
# ## salaryinusd	The salary in USD (FX rate divided by avg. USD rate for the respective year via fxdata.foorilla.com).
#
#
# ## employee_residence	Employee's primary country of residence in during the work year as an ISO 3166 country code.
#
# ## remote_ratio	The overall amount of work done remotely, possible values are as follows: 0 No remote work (less than 20%) 50 Partially remote 100 Fully remote (more than 80%)
#
# ## company_location	The country of the employer's main office or contracting branch as an ISO 3166 country code.
#
# ## company_size	The average number of people that worked for the company during the year: S less than 50 employees (small) M 50 to 250 employees (medium) L more than 250 employees (large)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Experience Level Exploration

# %%
# this extracts the number of employees with the experience level
df['experience_level'].value_counts()
# Out:
# SE    280
# MI    213
# EN     88
# EX     26
# Name: experience_level, dtype: int64

# %%
# pie chart of experience level

df['experience_level'].value_counts().plot(kind='pie', autopct='%1.0f%%');
plt.title('Employee Experience Level');

# %% [markdown]
# ## Job Titles Exploration

# %%
#sort job title distribution
df['job_title'].value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
# bar chart of job title distribution

df['job_title'].value_counts().plot(kind='bar')

#plt.figure(figsize=12,8)
plt.ylabel('Number of employee')
plt.xlabel('Job title')
plt.title('Distribution of Job Title')
# Out:
# Text(0.5, 1.0, 'Distribution of Job Title')

# %%
df['job_title'].value_counts().plot(kind='pie', autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='job_title'>

# %%
jj= df['employment_type'].value_counts(ascending=True)
jj
# Out:
# FL      4
# CT      5
# PT     10
# FT    588
# Name: employment_type, dtype: int64

# %%
# pie chart of employment type distribution
df['employment_type'].value_counts().plot(kind='pie', autopct='%1.0f%%');

# %%
# bar chart of employment type distribution

sns.histplot(df['employment_type'].values);
plt.ylabel('Number of employee');
plt.xlabel('Employment Type');
plt.title('Distribution of Employment Type');
plt.show;

# %%
#  bar chart of employment type distribution

df['employment_type'].value_counts().plot(kind='bar', legend='employment_type')
plt.ylabel('Number of Employee')
plt.xlabel('Employment Type')
plt.title('Distribution of Job Title')
# Out:
# Text(0.5, 1.0, 'Distribution of Job Title')

# %% [markdown]
# ## Distribution of Employee Residence

# %%
# Distribution of Employee Residence

df['employee_residence'].value_counts()
# Out:
# US    332
# GB     44
# IN     30
# CA     29
# DE     25
# FR     18
# ES     15
# GR     13
# JP      7
# PT      6
# BR      6
# PK      6
# NL      5
# PL      4
# IT      4
# RU      4
# AE      3
# AT      3
# VN      3
# TR      3
# AU      3
# RO      2
# BE      2
# SG      2
# SI      2
# DK      2
# HU      2
# NG      2
# MX      2
# BO      1
# MY      1
# TN      1
# IE      1
# DZ      1
# AR      1
# CZ      1
# JE      1
# LU      1
# PR      1
# RS      1
# EE      1
# CL      1
# HK      1
# KE      1
# MD      1
# CO      1
# IR      1
# CN      1
# MT      1
# UA      1
# IQ      1
# HN      1
# BG      1
# HR      1
# PH      1
# NZ      1
# CH      1
# Name: employee_residence, dtype: int64

# %%
# Bar chart Distribution of Employee Residence

df['employee_residence'].value_counts().plot(kind='bar')

plt.figure(figsize=(10,16))

# %%
# company location 

# company size

# %%
df['company_location'].value_counts()
# Out:
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# LU      3
# PK      3
# BR      3
# AE      3
# MX      3
# AU      3
# TR      3
# DK      3
# IT      2
# CZ      2
# SI      2
# RU      2
# CH      2
# NG      2
# CN      2
# BE      2
# VN      1
# EE      1
# AS      1
# DZ      1
# MY      1
# MD      1
# KE      1
# SG      1
# CO      1
# IR      1
# CL      1
# MT      1
# IL      1
# UA      1
# IQ      1
# RO      1
# HR      1
# NZ      1
# HU      1
# HN      1
# IE      1
# Name: company_location, dtype: int64

# %%
dflocation = df['company_location'].value_counts().plot(kind= 'bar')

#plt.plot(data= dflocation)

# %%
df['company_size'].value_counts()
# Out:
# M    326
# L    198
# S     83
# Name: company_size, dtype: int64

# %%
df['company_size'].value_counts().plot(kind='pie', autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='company_size'>

# %% [markdown]
# ## Work-year Exploration

# %%
df['work_year'].value_counts()
# Out:
# 2022    318
# 2021    217
# 2020     72
# Name: work_year, dtype: int64

# %%
df['work_year'].value_counts().plot(kind='pie', autopct= '%1.0f%%');

# %% [markdown]
# ## Exploration of Employee Salary in USD

# %%
sns.histplot(df['salary_in_usd'].values);
plt.ylabel('Number of Employee')
plt.xlabel('Salary in USD ')
plt.title('Distribution of Employee Salary in USD')
#plot(kind='bar');
# Out:
# Text(0.5, 1.0, 'Distribution of Employee Salary in USD')

# %%
sns.boxplot(df['salary_in_usd'].values)
plt.ylabel('Number of Employee')
plt.xlabel('Salary in USD ')
plt.title('Distribution of Employee Salary in USD')
# Out:
# C:\Users\COMPUTER SCIENCE\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribution of Employee Salary in USD')

# %% [markdown]
# ## about 10 outliers were identified here

# %%
df['salary_in_usd'].mean()
# Out:
# 112297.86985172982

# %% [markdown]
# ## Remote work Ratio identification

# %%
df['remote_ratio'].value_counts()
# Out:
# 100    381
# 0      127
# 50      99
# Name: remote_ratio, dtype: int64

# %%
df.head(1)
# Out:
#    Unnamed: 0  work_year experience_level employment_type       job_title  \
# 0           0       2020               MI              FT  Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
#
#   company_location company_size
# 0               DE            L

# %%
#df['remote_ratio'].value_counts().plot(kind='bar');

# a function to rename the remote job column into categorical columns

def Remote(x):
        if x==0:
            return 'NO REMOTE'
        elif x==50:
            return 'PARTIALLY REMOTE'
        elif x==100:
            return 'FULLY REMOTE'

df['new_remote_ratio']= df['remote_ratio'].apply(Remote)

df.head()
#sns.countplot(data=df, x= 'remote_ratio');
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size  \
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
# pie chart showing ratio of remote work
df['new_remote_ratio'].value_counts().plot(kind='pie',autopct='%1.0f%%');
plt.title('Ratio of Remote Work');

# %%
# bar chart showing ratio of remote work
sns.countplot(data=df, x='new_remote_ratio')
plt.xlabel('Level of Remote Job')
plt.ylabel('No of employee')
# Out:
# Text(0, 0.5, 'No of employee')

# %%
# Use subplots to visualize all the features at a glance


fig, axes = plt.subplots(2,4, figsize=(20,10))

# Categorical features
sns.countplot(x='experience_level', data=df, ax=axes[0,0])
sns.countplot(x='employment_type', data=df, ax=axes[0,1])
sns.countplot(x='job_title', data=df, ax=axes[0,2])
sns.countplot(x='salary_currency', data=df, ax=axes[0,3])
sns.countplot(x='salary_in_usd', data=df, ax=axes[1,0])
sns.countplot(x='employee_residence', data=df, ax=axes[1,1]) 
sns.countplot(x='company_location', data=df, ax=axes[1,1]) 
sns.countplot(x='company_size', data=df, ax=axes[1,2]) 
# Numerical Features
sns.histplot(x='work_year', data=df, ax=axes[1,3])

#sns.histplot(x='salary', data=df, ax=axes[2,1])

#sns.histplot(x='salary_in_usd', data=df, ax=axes[2,2])

#sns.histplot(x='remote_ratio', data=df, ax=axes[2,3])                  
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # BIVARIATE ANALYSIS

# %% [markdown]
# ## REMOTE WORK BY WORK YEAR ANALYSIS

# %%
sns.countplot(data=df, x='work_year', hue='new_remote_ratio')
plt.ylabel('Number of Employee')
plt.xlabel('Level of Remote Work ')
plt.title('Distribution of Remote Work by Work Year')
# Out:
# Text(0.5, 1.0, 'Distribution of Remote Work by Work Year')

# %%
plt.figure(figsize=(6,4))
plt.title('DISTRIBUTION OF REMOTE WORK BY WORK-YEAR')
sns.countplot(data=df, x='new_remote_ratio', hue='work_year')
plt.xlabel('Level of Remote Work')
plt.ylabel('Count of Workers')
plt.show()

# %%
sns.countplot(data=df, x ='employment_type',  hue='experience_level')
# Out:
# <AxesSubplot:xlabel='employment_type', ylabel='count'>

# %% [markdown]
# # Experience Level Analysis
#
# ## Employment Type by Experience Level

# %%
def Employ_level(x):
        if x=='FT':
            return 'FULL-TIME'
        elif x=='FL':
            return 'FREELANCE'
        elif x=='PT':
            return 'PART-TIME'
        elif x=='CT':
            return 'CONTRACT'

df['new_Employ_level']= df['employment_type'].apply(Employ_level)

df.head(1)
# Out:
#    Unnamed: 0  work_year experience_level employment_type       job_title  \
# 0           0       2020               MI              FT  Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
#
#   company_location company_size new_remote_ratio          TopJob  \
# 0               DE            L        NO REMOTE  Data Scientist
#
#   new_Employ_level
# 0        FULL-TIME

# %%
plt.figure(figsize=(7,5))
plt.title('Employment Type by Experience Level')


#newdf=df['employment_type'].ascending='true'
sns.countplot(data=df, x ='new_Employ_level',  hue='experience_level')
plt.xlabel('Employment Type')
plt.ylabel('Count of Workers')
plt.show()

# %% [markdown]
# # Top 3 Job Title by Experience Level

# %%
job= df['job_title'].value_counts().head(3)
job
# Out:
# Data Scientist    143
# Data Engineer     132
# Data Analyst       97
# Name: job_title, dtype: int64

# %%
# a function that creates a new column capturing the top 3 jobs
def Top_Job(x):
    if x=='Data Scientist':
        return 'Data Scientist'
    elif x=='Data Engineer':
        return 'Data Engineer'
    elif x=='Data Analyst':
        return 'Data Analyst'
    
        
df['TopJob']= df['job_title'].apply(Top_Job)

# %%
plt.figure(figsize=(6,4))
plt.title('Top Three Jobs by Experience Level')
sns.countplot(data=df, x='TopJob',  hue='experience_level');
plt.xlabel('Top Three Jobs')
plt.ylabel('Count of Workers')
plt.show()

# %% [markdown]
# ## Company Size by Experience Level

# %%
def COY_SIZE(x):
        if x=='L':
            return 'LARGE'
        elif x=='S':
            return 'SMALL'
        elif x=='M':
            return 'MEDIUM'
       

df['new_ECOY_SIZE']= df['company_size'].apply(COY_SIZE)

df.head(1)
# Out:
#    Unnamed: 0  work_year experience_level employment_type       job_title  \
# 0           0       2020               MI              FT  Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
#
#   company_location company_size new_remote_ratio          TopJob  \
# 0               DE            L        NO REMOTE  Data Scientist
#
#   new_Employ_level new_ECOY_SIZE
# 0        FULL-TIME         LARGE

# %%
sns.countplot(data=df, x='new_ECOY_SIZE', hue= 'experience_level');
plt.xlabel('Company Size')
plt.ylabel('No of employee')
# Out:
# Text(0, 0.5, 'No of employee')

# %% [markdown]
# # Company Location Analysis
#
# ## Experience Level

# %%
# a function that creates a new column capturing 10 cities with highest concentration of branches 
def Top_branch_Town(x):
      
    if x=='US':
        return 'US'
    elif x=='GB':
        return 'GB'
    elif x=='CA':
        return 'CA'
    elif x=='DE':
        return 'DE'
    if x=='IN':
        return 'IN'
    elif x=='FR':
        return 'FR'
    elif x=='ES':
        return 'ES'
    if x=='GR':
        return 'GR'
    elif x=='JP':
        return 'JP'
    elif x=='NL':
        return 'NL'
    elif x=='AT':
        return 'AT'
    elif x=='PT':
        return 'PT'
    elif x=='PL' :
        return 'PL'
df['Topmost_branch_town']= df['company_location'].apply(Top_branch_Town)
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size  \
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
joy=df['Topmost_branch_town'].value_counts()
joy
# Out:
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# Name: Topmost_branch_town, dtype: int64

# %%
# I picked locations that had a minimum of 4 branches
sns.countplot(data=df, x='Topmost_branch_town', hue='experience_level')
# Out:
# <AxesSubplot:xlabel='Topmost_branch_town', ylabel='count'>

# %% [markdown]
# ## the question here is that why is there no executive officer cadre in Great Britain, whereas, PL with lower number of staff has an Executive staff with them.

# %%
Salary Analysis
5.1. Salary by work year
5.2. Salary by Experience Level
5.3. Salary by Company Size
5.4. Highest salaries by job title
5.5. Average Salary by Company Location

# %%
df.head(1)
# Out:
#    Unnamed: 0  work_year experience_level employment_type       job_title  \
# 0           0       2020               MI              FT  Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
#
#   company_location company_size new_remote_ratio          TopJob  \
# 0               DE            L        NO REMOTE  Data Scientist
#
#   new_Employ_level new_ECOY_SIZE Topmost_branch_town
# 0        FULL-TIME         LARGE                  DE

# %% [markdown]
# ## Salary by work year

# %%
sdf = df['salary_in_usd'].value_counts().head(10)
sdf
# Out:
# 100000    15
# 120000    12
# 150000    12
# 200000    10
# 135000     9
# 170000     8
# 160000     8
# 140000     8
# 80000      8
# 130000     8
# Name: salary_in_usd, dtype: int64

# %%
# a function that creates a new column capturing 10 most frequent salary in usd 
def Freq_salary(x):  
    if x==80000:
        return '80000'
    elif x==100000:
        return '100000'
    elif x==120000:
        return '120000'
    elif x==150000:
        return '150000'
    elif x==150000:
        return '200000'
    elif x==200000:
        return '50000'
    elif x==170000 :
        return '170000 '
    elif x==140000:
        return '140000'
    elif x==170000 :
        return '170000 '
    elif x==160000:
        return '160000'
    
    
df['Freqeunt_salary_']= df['salary_in_usd'].apply(Freq_salary)
df.head(1)
# Out:
#    Unnamed: 0  work_year experience_level employment_type       job_title  \
# 0           0       2020               MI              FT  Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
#
#   company_location company_size new_remote_ratio          TopJob  \
# 0               DE            L        NO REMOTE  Data Scientist
#
#   new_Employ_level new_ECOY_SIZE Topmost_branch_town Freqeunt_salary_  \
# 0        FULL-TIME         LARGE                  DE             None
#
#   Frequent_salary2_
# 0             70000

# %% [markdown]
# # Salary Analysis
#
# ## Salary by work year

# %%
plt.figure(figsize=(6,4))
plt.title('Salary by Work-year')
sns.countplot(data=df, x='salary_in_usd', hue='work_year');
plt.xlabel('Salary')
plt.ylabel('No of Emplyees')
plt.show()

# %% [markdown]
# ## the result here in salary in usd by workyear shows that more people are earning far higher in 2022 than they were earning in 2020 and 2021

# %%
# the first most common 8 salaries were selected to compare the no of employees earning the amount in a 3 year period  
plt.figure(figsize=(6,4))
plt.title('Salary by Work-year')
sns.countplot(data=df, x='Freqeunt_salary_', hue='work_year');
plt.xlabel('Salary')
plt.ylabel('No of Emplyees')
plt.show()

# %% [markdown]
# ## Salary by Experience Level

# %%
plt.figure(figsize=(6,4))
plt.title('Salary by Experience Level')
sns.countplot(data=df, x='salary_in_usd', hue='experience_level');
plt.xlabel('Salary')
plt.ylabel('No of Emplyees')
plt.show()

# %%
# the first most common 8 salaries were selected to compare the no of employees earning the amount in a 3 year period  by experience level
#second 

plt.figure(figsize=(8,4))
plt.title('Salary by Experience Level')
sns.countplot(data=df, x='Freqeunt_salary_', hue='experience_level');
plt.xlabel('Salary')
plt.ylabel('No of Employees')
plt.show()

# %% [markdown]
# ## Salary by Company Size

# %%
# the first most common 8 salaries were selected to compare the no of employees earning the amount in a 3 year period  by company size
plt.figure(figsize=(8,4))
plt.title('Salary by Company Size')
sns.countplot(data=df, x='Freqeunt_salary_', hue='company_size');
plt.xlabel('Salary')
plt.ylabel('No of Employees')
plt.show()

# %%
#salary in usd by company size
plt.figure(figsize=(6,4))
plt.title('Salary by Company Size')
sns.countplot(data=df, x= 'salary_in_usd', hue='company_size');
plt.xlabel('Salary')
plt.ylabel('No of Employees')
plt.show()

# %% [markdown]
# ## Highest salaries by job title

# %%
# a function that creates a new column capturing 8 topmost earners 

def High_salary(x):  
    
    if x==30400000:
        return '30400000'
    elif x==11000000:
        return '11000000'
    elif x==8500000:
        return '8500000'
    elif x==7000000:
        return '7000000'
    elif x==6000000:
        return '6000000'
    elif x==4900000:
        return '4900000'
    elif x== 4450000 :
        return '4450000 '
    elif x==4000000:
        return '4000000'

df['Highest_salary_']= df['salary'].apply(High_salary)
df.head(1)
# Out:
#    Unnamed: 0  work_year experience_level employment_type       job_title  \
# 0           0       2020               MI              FT  Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
#
#   company_location company_size new_remote_ratio          TopJob  \
# 0               DE            L        NO REMOTE  Data Scientist
#
#   new_Employ_level new_ECOY_SIZE Topmost_branch_town Freqeunt_salary_  \
# 0        FULL-TIME         LARGE                  DE             None
#
#   Frequent_salary2_ Highest_salary_
# 0             70000            None

# %% [markdown]
# ## Highest Salaries by Job Title

# %%
plt.figure(figsize=(10,10))
plt.title('Salary by Job Title')
sns.countplot(data=df, x='Highest_salary_', hue='job_title');
plt.xlabel('Salary')
plt.ylabel('No of Emplyees')
plt.show()

# %% [markdown]
# ### I picked some 8 topmost earners, and found that  Data Scientist and Director of Data Science had the highest pay, £11,000,000
#
#
# ### Data science manager and principal data scientist had the next level of high pay
#
#
#
# ### Data Science Consultant also had a share

# %%
sal = round(df['salary'].mean())
sal
# Out:
# 324000

# %% [markdown]
# ## Average Salary by Company Location

# %%
# average salary
avsal = df.groupby('company_location')['salary'].mean().sort_values()
avsal
# Out:
# company_location
# VN    4.000000e+03
# IR    4.000000e+03
# KE    9.272000e+03
# PK    1.333333e+04
# UA    1.340000e+04
# MD    1.800000e+04
# HN    2.000000e+04
# CO    2.184400e+04
# MT    2.400000e+04
# EE    3.000000e+04
# NG    3.000000e+04
# IT    3.110000e+04
# LU    3.833333e+04
# MY    4.000000e+04
# HR    4.000000e+04
# PT    4.210000e+04
# GR    4.736364e+04
# ES    4.738286e+04
# NL    4.910000e+04
# CZ    4.949950e+04
# SI    5.400000e+04
# FR    5.688133e+04
# RO    6.000000e+04
# GB    6.229481e+04
# AT    6.400000e+04
# IE    6.500000e+04
# BR    6.520000e+04
# DE    7.128996e+04
# BE    7.250000e+04
# AE    1.000000e+05
# IQ    1.000000e+05
# DZ    1.000000e+05
# CA    1.153067e+05
# SG    1.200000e+05
# NZ    1.250000e+05
# AU    1.303333e+05
# PL    1.425000e+05
# RU    1.575000e+05
# IL    1.600000e+05
# TR    1.793333e+05
# DK    1.850000e+05
# US    1.877160e+05
# CN    1.995000e+05
# CH    2.750000e+05
# MX    2.793333e+05
# AS    1.335000e+06
# ...

# %%
plt.title('Average Salary by Branch Location')
avsal.plot(kind='pie', autopct='%1.0f%%')
# Out:
# <AxesSubplot:title={'center':'Average Salary by Branch Location'}, ylabel='salary'>

# %% [markdown]
# # interestingly,, 5 location collect 94% of the salary being paid by the organisation. out of over 25 locations

# %%
plt.figure(figsize=(8,5))
plt.title('Average Salary by Branch Location')
avsal.plot(kind='bar')
plt.xlabel('Branch Location')
plt.ylabel('Average Salary')
plt.show()
